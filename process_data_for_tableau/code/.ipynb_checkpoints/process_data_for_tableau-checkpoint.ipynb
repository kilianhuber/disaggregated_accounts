# %%
import pandas as pd
from pathlib import Path
import regex as re

# %%
root_folderpath = Path(r"C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau")
matrices_folderpath = Path(root_folderpath / r"data\matrices")
vectors_individual_folderpath = Path(root_folderpath / r"data\vectors_individual")
vectors_consumer_flows_folderpath = Path(root_folderpath / r"data\vectors_consumer_flows")
vectors_producer_flows_folderpath = Path(root_folderpath / r"data\vectors_producer_flows")
muni_names_filepath = Path(root_folderpath / r"data\crosswalk\dk_municipalities_code_to_name.xlsx")
output_folderpath = Path(root_folderpath / r"output_csv")

# %%
muni_names_crosswalk = pd.read_excel(muni_names_filepath)
muni_names_crosswalk = muni_names_crosswalk.convert_dtypes()
muni_names_crosswalk.dtypes
# Out:
# code    string
# name    string
# dtype: object

# %% [markdown]
# # Common Functions

# %%
def convert_munis_to_names(df, muni_names_crosswalk):
    df = df.copy()
    print("Initial state:")
    print(df.shape, df.columns)
        
    # Remove columns like 'prod_cell' and 'cust_cell'
    for col in df.columns:
        if 'cell' in col:
            df = df.drop(col, axis=1)
    print("After removing 'cell' variables:")
    print(df.shape, df.columns)
        
    # Convert 'muni' columns into string
    for col in df.columns:
        if 'muni' in col:
            df[col] = df[col].astype('string')
    print(df.dtypes)

    # Convert values in sectors to integers, i.e. remove the 's' in 's01'
    for col in df.columns:
        if 'sector' in col:
            df[col] = df[col].str.replace('s','')

    # Convert munis into muni names, and drop the original munis.
    df_merge = df.copy()
    for col in df_merge.columns:
        if '_muni' in col:
            muni_name = col + '_name'
            print("Processing:", col)
            print("Before merge:", df.shape, df_merge.columns)
            df_merge = df_merge.merge(muni_names_crosswalk, left_on=col, right_on='code', how='inner', validate='m:1')
            assert(df_merge.shape[0] == df.shape[0])
            print("After merge:", df.shape, df_merge.columns)
            df_merge = df_merge.rename(columns={'name':muni_name})
            df_merge = df_merge.drop([col, 'code'], axis=1)
            print("After processing:", df.shape, df_merge.columns)
    
    return df_merge

# %%
def save_df_to_csv(df, input_filepath, output_folderpath, suffix=''):
    output_filename = input_filepath.stem + suffix + '.csv'
    output_filepath = Path(output_folderpath / output_filename)
    df.to_csv(output_filepath, index=False)
    print("Saved as:", output_filepath)

# %% [markdown]
# # Process matrices

# %%
for matrix_filepath in matrices_folderpath.iterdir():
    print(matrix_filepath)
    df = pd.read_csv(matrix_filepath, low_memory=False)
    
    # Create a new df where munis are converted to names, then save as csv
    df_merge = convert_munis_to_names(df, muni_names_crosswalk)
    save_df_to_csv(df_merge, matrix_filepath, output_folderpath)
    
    print('\n-')
# Out:
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\matrices\Domestic consumer spending matrix (predicted).csv
# Initial state:
# (7260624, 7) Index(['cust_muni', 'cust_sector', 'cust_cell', 'spend_muni', 'spend_sector',
#        'spend_cell', 's_'],
#       dtype='object')
# After removing 'cell' variables:
# (7260624, 5) Index(['cust_muni', 'cust_sector', 'spend_muni', 'spend_sector', 's_'], dtype='object')
# cust_muni        string
# cust_sector      object
# spend_muni       string
# spend_sector     object
# s_              float64
# dtype: object
# Processing: cust_muni
# Before merge: (7260624, 5) Index(['cust_muni', 'cust_sector', 'spend_muni', 'spend_sector', 's_'], dtype='object')
# After merge: (7260624, 5) Index(['cust_muni', 'cust_sector', 'spend_muni', 'spend_sector', 's_', 'code',
#        'name'],
#       dtype='object')
# After processing: (7260624, 5) Index(['cust_sector', 'spend_muni', 'spend_sector', 's_', 'cust_muni_name'], dtype='object')
# Processing: spend_muni
# Before merge: (7260624, 5) Index(['cust_sector', 'spend_muni', 'spend_sector', 's_', 'cust_muni_name'], dtype='object')
# After merge: (7260624, 5) Index(['cust_sector', 'spend_muni', 'spend_sector', 's_', 'cust_muni_name',
#        'code', 'name'],
#       dtype='object')
# After processing: (7260624, 5) Index(['cust_sector', 'spend_sector', 's_', 'cust_muni_name',
#        'spend_muni_name'],
#       dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Domestic consumer spending matrix (predicted).csv
#
# -
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\matrices\Domestic intermediates.csv
# Initial state:
# (7001316, 5) Index(['supplier_muni', 'supplier_sector', 'user_muni', 'user_sector',
#        'trade_'],
#       dtype='object')
# After removing 'cell' variables:
# (7001316, 5) Index(['supplier_muni', 'supplier_sector', 'user_muni', 'user_sector',
#        'trade_'],
#       dtype='object')
# supplier_muni       string
# supplier_sector     object
# user_muni           string
# user_sector         object
# trade_             float64
# dtype: object
# Processing: supplier_muni
# Before merge: (7001316, 5) Index(['supplier_muni', 'supplier_sector', 'user_muni', 'user_sector',
#        'trade_'],
#       dtype='object')
# After merge: (7001316, 5) Index(['supplier_muni', 'supplier_sector', 'user_muni', 'user_sector',
#        'trade_', 'code', 'name'],
#       dtype='object')
# After processing: (7001316, 5) Index(['supplier_sector', 'user_muni', 'user_sector', 'trade_',
#        'supplier_muni_name'],
#       dtype='object')
# Processing: user_muni
# Before merge: (7001316, 5) Index(['supplier_sector', 'user_muni', 'user_sector', 'trade_',
#        'supplier_muni_name'],
#       dtype='object')
# After merge: (7001316, 5) Index(['supplier_sector', 'user_muni', 'user_sector', 'trade_',
#        'supplier_muni_name', 'code', 'name'],
#       dtype='object')
# After processing: (7001316, 5) Index(['supplier_sector', 'user_sector', 'trade_', 'supplier_muni_name',
#        'user_muni_name'],
#       dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Domestic intermediates.csv
#
# -
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\matrices\Labor compensation.csv
# Initial state:
# (7260624, 7) Index(['cust_cell', 'prod_cell', 'comp_', 'prod_muni', 'prod_sector',
#        'cust_muni', 'cust_sector'],
#       dtype='object')
# After removing 'cell' variables:
# (7260624, 5) Index(['comp_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector'], dtype='object')
# comp_          float64
# prod_muni       string
# prod_sector     object
# cust_muni       string
# cust_sector     object
# dtype: object
# Processing: prod_muni
# Before merge: (7260624, 5) Index(['comp_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector'], dtype='object')
# After merge: (7260624, 5) Index(['comp_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector', 'code',
#        'name'],
#       dtype='object')
# After processing: (7260624, 5) Index(['comp_', 'prod_sector', 'cust_muni', 'cust_sector', 'prod_muni_name'], dtype='object')
# Processing: cust_muni
# Before merge: (7260624, 5) Index(['comp_', 'prod_sector', 'cust_muni', 'cust_sector', 'prod_muni_name'], dtype='object')
# After merge: (7260624, 5) Index(['comp_', 'prod_sector', 'cust_muni', 'cust_sector', 'prod_muni_name',
#        'code', 'name'],
#       dtype='object')
# After processing: (7260624, 5) Index(['comp_', 'prod_sector', 'cust_sector', 'prod_muni_name',
#        'cust_muni_name'],
#       dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Labor compensation.csv
#
# -
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\matrices\Mixed income from non-corporate producers.csv
# Initial state:
# (7260624, 7) Index(['cust_cell', 'prod_cell', 'mixedinc_', 'prod_muni', 'prod_sector',
#        'cust_muni', 'cust_sector'],
#       dtype='object')
# After removing 'cell' variables:
# (7260624, 5) Index(['mixedinc_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector'], dtype='object')
# mixedinc_      float64
# prod_muni       string
# prod_sector     object
# cust_muni       string
# cust_sector     object
# dtype: object
# Processing: prod_muni
# Before merge: (7260624, 5) Index(['mixedinc_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector'], dtype='object')
# After merge: (7260624, 5) Index(['mixedinc_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector',
#        'code', 'name'],
#       dtype='object')
# After processing: (7260624, 5) Index(['mixedinc_', 'prod_sector', 'cust_muni', 'cust_sector',
#        'prod_muni_name'],
#       dtype='object')
# Processing: cust_muni
# Before merge: (7260624, 5) Index(['mixedinc_', 'prod_sector', 'cust_muni', 'cust_sector',
#        'prod_muni_name'],
#       dtype='object')
# After merge: (7260624, 5) Index(['mixedinc_', 'prod_sector', 'cust_muni', 'cust_sector',
#        'prod_muni_name', 'code', 'name'],
#       dtype='object')
# After processing: (7260624, 5) Index(['mixedinc_', 'prod_sector', 'cust_sector', 'prod_muni_name',
#        'cust_muni_name'],
#       dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Mixed income from non-corporate producers.csv
#
# -
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\matrices\Surplus of corporate producers to consumers (dividends).csv
# Initial state:
# (7260624, 7) Index(['cust_cell', 'prod_cell', 'surplus_', 'prod_muni', 'prod_sector',
#        'cust_muni', 'cust_sector'],
#       dtype='object')
# After removing 'cell' variables:
# (7260624, 5) Index(['surplus_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector'], dtype='object')
# surplus_       float64
# prod_muni       string
# prod_sector     object
# cust_muni       string
# cust_sector     object
# dtype: object
# Processing: prod_muni
# Before merge: (7260624, 5) Index(['surplus_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector'], dtype='object')
# After merge: (7260624, 5) Index(['surplus_', 'prod_muni', 'prod_sector', 'cust_muni', 'cust_sector',
#        'code', 'name'],
#       dtype='object')
# After processing: (7260624, 5) Index(['surplus_', 'prod_sector', 'cust_muni', 'cust_sector',
#        'prod_muni_name'],
#       dtype='object')
# Processing: cust_muni
# Before merge: (7260624, 5) Index(['surplus_', 'prod_sector', 'cust_muni', 'cust_sector',
#        'prod_muni_name'],
#       dtype='object')
# After merge: (7260624, 5) Index(['surplus_', 'prod_sector', 'cust_muni', 'cust_sector', 'prod_muni_name',
#        'code', 'name'],
#       dtype='object')
# After processing: (7260624, 5) Index(['surplus_', 'prod_sector', 'cust_sector', 'prod_muni_name',
#        'cust_muni_name'],
#       dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Surplus of corporate producers to consumers (dividends).csv
#
# -

# %% [markdown]
# # Process vectors

# %% [markdown]
# ## Process individual vectors (foreign consumer spending, surplus of owner-occupied housing to consumers)
# Note: surplus of owner-occupied housing to consumers has both cust and prod cell in the raw data, but the prod cell is always cust muni + s88, so we want to remove it. This effectively reduces the matrix into a vector.

# %%
for vector_individual_filepath in vectors_individual_folderpath.iterdir():
    print(vector_individual_filepath)
    df = pd.read_csv(vector_individual_filepath, low_memory=False)
    
    # Create a new df where munis are converted to names, then save as csv
    df_merge = convert_munis_to_names(df, muni_names_crosswalk)
    save_df_to_csv(df_merge, vector_individual_filepath, output_folderpath)
    
    print('\n-')
# Out:
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_individual\Foreign consumer spending (predicted).csv
# Initial state:
# (2744, 4) Index(['cust_muni', 'cust_sector', 'cust_cell', 's_foreign_'], dtype='object')
# After removing 'cell' variables:
# (2744, 3) Index(['cust_muni', 'cust_sector', 's_foreign_'], dtype='object')
# cust_muni       string
# cust_sector     object
# s_foreign_     float64
# dtype: object
# Processing: cust_muni
# Before merge: (2744, 3) Index(['cust_muni', 'cust_sector', 's_foreign_'], dtype='object')
# After merge: (2744, 3) Index(['cust_muni', 'cust_sector', 's_foreign_', 'code', 'name'], dtype='object')
# After processing: (2744, 3) Index(['cust_sector', 's_foreign_', 'cust_muni_name'], dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Foreign consumer spending (predicted).csv
#
# -
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_individual\Surplus of owner-occupied housing to consumers.csv
# Initial state:
# (2744, 5) Index(['cust_cell', 'prod_cell', 'surplus_', 'cust_muni', 'cust_sector'], dtype='object')
# After removing 'cell' variables:
# (2744, 3) Index(['surplus_', 'cust_muni', 'cust_sector'], dtype='object')
# surplus_       float64
# cust_muni       string
# cust_sector     object
# dtype: object
# Processing: cust_muni
# Before merge: (2744, 3) Index(['surplus_', 'cust_muni', 'cust_sector'], dtype='object')
# After merge: (2744, 3) Index(['surplus_', 'cust_muni', 'cust_sector', 'code', 'name'], dtype='object')
# After processing: (2744, 3) Index(['surplus_', 'cust_sector', 'cust_muni_name'], dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Surplus of owner-occupied housing to consumers.csv
#
# -

# %% [markdown]
# ## Process consumer flows vectors

# %%
def process_vector(vector_filepath, player):
    # The csv files come in different types. Process each accordingly.
    # The goal is to get 3 columns per df: cust_muni, cust_sector, and the variable of interest.
    print(vector_filepath)
    df = pd.read_csv(vector_filepath, low_memory=False, header=None)
    var_name = vector_filepath.stem

    if df.shape[0] < df.shape[1]:
        df = df.transpose()

    if df.shape[1] > 2:
        df = pd.read_csv(vector_filepath, low_memory=False)
        df = df.drop(f'{player}_cell', axis=1)
        var_name_in_table = df.columns[-1]
        df[f'{player}_muni'] = df[f'{player}_muni'].astype('str')
        df[f'{player}_sector'] = df[f'{player}_sector'].str.replace('s','').astype('str')
        df['var_name'] = var_name
        df = df.rename(columns={var_name_in_table:'value'})
    elif df.shape[1] == 2:
        df.columns = [f'{player}_cell', 'value'] 
        df['var_name'] = var_name 
        df[f'{player}_muni'] = df[f'{player}_cell'].str[1:4].astype('str')
        df[f'{player}_sector'] = df[f'{player}_cell'].str[-2:].astype('str')
        df = df.drop(f'{player}_cell', axis=1)
    
    print("Processed df_vector.shape:", df.shape)
    return df

# %%
def compile_vectors_into_df(vectors_consumer_flows_folderpath, player):
    df = pd.DataFrame()
    for vector_filepath in vectors_consumer_flows_folderpath.iterdir():
        if vector_filepath.suffix == '.csv':
            df_vector = process_vector(vector_filepath, player)
            if df.shape == (0,0):
                df = df_vector
                print("df.shape:", df.shape)
            else:
                df = pd.concat([df, df_vector], axis=0)
                print("df.shape:", df.shape)
    return df

# %%
df = compile_vectors_into_df(vectors_consumer_flows_folderpath, player='cust')
df_merge = convert_munis_to_names(df, muni_names_crosswalk)
save_df_to_csv(df_merge, Path(output_folderpath / 'Additional consumer flows.csv'), output_folderpath)
df_merge
# Out:
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer adjustment for pension entitlements received.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (2744, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer gross saving.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (5488, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer interest paid.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (8232, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer interest received.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (10976, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer natural resource rents paid.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (13720, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer natural resource rents received.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (16464, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer non-product taxes paid.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (19208, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer other transfers paid.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (21952, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer other transfers received.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (24696, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer pension investment income.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (27440, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer product taxes paid (predicted).csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (30184, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer social benefits received.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (32928, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_consumer_flows\Consumer social contributions paid.csv
# Processed df_vector.shape: (2744, 4)
# df.shape: (35672, 4)
# Initial state:
# (35672, 4) Index(['value', 'var_name', 'cust_muni', 'cust_sector'], dtype='object')
# After removing 'cell' variables:
# (35672, 4) Index(['value', 'var_name', 'cust_muni', 'cust_sector'], dtype='object')
# value          object
# var_name       object
# cust_muni      string
# cust_sector    object
# dtype: object
# Processing: cust_muni
# Before merge: (35672, 4) Index(['value', 'var_name', 'cust_muni', 'cust_sector'], dtype='object')
# After merge: (35672, 4) Index(['value', 'var_name', 'cust_muni', 'cust_sector', 'code', 'name'], dtype='object')
# After processing: (35672, 4) Index(['value', 'var_name', 'cust_sector', 'cust_muni_name'], dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Additional consumer flows.csv
#                     value                                           var_name  \
# 0        197366365.711175  Consumer adjustment for pension entitlements r...
# 1        308340477.702592  Consumer adjustment for pension entitlements r...
# 2          199690524.2474  Consumer adjustment for pension entitlements r...
# 3       1347486676.418711  Consumer adjustment for pension entitlements r...
# 4        223900554.813007  Consumer adjustment for pension entitlements r...
# ...                   ...                                                ...
# 35667   341570823.1017025                 Consumer social contributions paid
# 35668   355249.3077520026                 Consumer social contributions paid
# 35669  188851304.60838416                 Consumer social contributions paid
# 35670  106507543.97043432                 Consumer social contributions paid
# 35671   7845760.114266208                 Consumer social contributions paid
#
#       cust_sector cust_muni_name
# 0              01      København
# 1              02      København
# 2              03      København
# 3              04      København
# 4              05      København
# ...           ...            ...
# 35667          24       Hjørring
# 35668          25       Hjørring
# 35669          26       Hjørring
# 35670          27       Hjørring
# 35671          28       Hjørring
#
# [35672 rows x 4 columns]

# %% [markdown]
# ## Process producer flows vectors

# %%
df = compile_vectors_into_df(vectors_producer_flows_folderpath, player='prod')
df_merge = convert_munis_to_names(df, muni_names_crosswalk)
save_df_to_csv(df_merge, Path(output_folderpath / 'Additional producer flows.csv'), output_folderpath)
df_merge
# Out:
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_producer_flows\Producer exports.csv
# Processed df_vector.shape: (2646, 4)
# df.shape: (2646, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_producer_flows\Producer imports.csv
# Processed df_vector.shape: (2646, 4)
# df.shape: (5292, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_producer_flows\Producer product taxes paid.csv
# Processed df_vector.shape: (2646, 4)
# df.shape: (7938, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_producer_flows\Producer sales to capital accumulation cell.csv
# Processed df_vector.shape: (2646, 4)
# df.shape: (10584, 4)
# C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\data\vectors_producer_flows\Producer sales to government.csv
# Processed df_vector.shape: (2646, 4)
# df.shape: (13230, 4)
# Initial state:
# (13230, 4) Index(['value', 'var_name', 'prod_muni', 'prod_sector'], dtype='object')
# After removing 'cell' variables:
# (13230, 4) Index(['value', 'var_name', 'prod_muni', 'prod_sector'], dtype='object')
# value          object
# var_name       object
# prod_muni      string
# prod_sector    object
# dtype: object
# Processing: prod_muni
# Before merge: (13230, 4) Index(['value', 'var_name', 'prod_muni', 'prod_sector'], dtype='object')
# After merge: (13230, 4) Index(['value', 'var_name', 'prod_muni', 'prod_sector', 'code', 'name'], dtype='object')
# After processing: (13230, 4) Index(['value', 'var_name', 'prod_sector', 'prod_muni_name'], dtype='object')
# Saved as: C:\Users\jasonjia\Dropbox\projects\disaggregated_accounts\process_data_for_tableau\output_csv\Additional producer flows.csv
#                    value                      var_name prod_sector  \
# 0           1612641024.0              Producer exports          01
# 1           1526094720.0              Producer exports          02
# 2           1520103040.0              Producer exports          03
# 3      5996545023.999999              Producer exports          04
# 4      2439924117.431438              Producer exports          05
# ...                  ...                           ...         ...
# 13225       1267504128.0  Producer sales to government          26
# 13226       1637282176.0  Producer sales to government          27
# 13227                0.0  Producer sales to government          77
# 13228                0.0  Producer sales to government          88
# 13229                0.0  Producer sales to government          99
#
#       prod_muni_name
# 0          København
# 1          København
# 2          København
# 3          København
# 4          København
# ...              ...
# 13225       Hjørring
# 13226       Hjørring
# 13227       Hjørring
# 13228       Hjørring
# 13229       Hjørring
#
# [13230 rows x 4 columns]
